# %% [markdown]
# # House Price Prediction
# Using this model by just providing the data regarding the housing locality, basic amenities, furnishing, and various
# other details model can predict the price of the house.
#
# #### The dataset was taken from the UCI repository

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Data Reading

# %%
housing=pd.read_csv("Housing.csv")
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
housing.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
housing.shape
# Out:
# (545, 13)

# %% [markdown]
# # Data Visualisation
# Plotting graphs between each predictor variable with the Price to see its affect

# %%
# Viualising the numerical variables
sns.pairplot(housing)

# %%
# Visualising the Categorical variables.

plt.figure(figsize=(20,20))
plt.subplot(2,3,1)
sns.boxplot(x='mainroad' , y='price', data=housing)

plt.subplot(2,3,2)
sns.boxplot(x='guestroom' , y='price', data=housing)

plt.subplot(2,3,3)
sns.boxplot(x='basement' , y='price', data=housing)

plt.subplot(2,3,4)
sns.boxplot(x='hotwaterheating' , y='price', data=housing)

plt.subplot(2,3,5)
sns.boxplot(x='airconditioning' , y='price', data=housing)

plt.subplot(2,3,6)
sns.boxplot(x='prefarea' , y='price', data=housing)
# Out:
# <AxesSubplot:xlabel='prefarea', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='furnishingstatus',y='price',data=housing)
# Out:
# <AxesSubplot:xlabel='furnishingstatus', ylabel='price'>

# %% [markdown]
# #### Therefore we have some variables which show linear relationship with the target variable (Price) therefore we can use Mutiple Linear regression in this model

# %% [markdown]
# # Preparing the Data for Modelling

# %% [markdown]
# ### 1) Dealing with categorical variables

# %%
# Mapping all the "Yes" to "1"  and allo the "No"  to "0"
varlist=["mainroad","guestroom","basement","hotwaterheating","airconditioning","prefarea"]
housing[varlist]=housing[varlist].apply(lambda x:x.map({'yes':1,'no':0}))
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %% [markdown]
# ### 2) Creation of Dummy variables

# %%
dummy=pd.get_dummies(housing["furnishingstatus"],drop_first=True)
dummy
# Out:
#      semi-furnished  unfurnished
# 0                 0            0
# 1                 0            0
# 2                 1            0
# 3                 0            0
# 4                 0            0
# ..              ...          ...
# 540               0            1
# 541               1            0
# 542               0            1
# 543               0            0
# 544               0            1
#
# [545 rows x 2 columns]

# %%
# Concatinating of the dummy with the housing data set 
housing=pd.concat([housing,dummy],axis=1)

housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus  semi-furnished  unfurnished
# 0        furnished               0            0
# 1        furnished               0            0
# 2   semi-furnished               1            0
# 3        furnished               0            0
# 4        furnished               0            0

# %%
housing.drop('furnishingstatus',axis=1,inplace=True)
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    semi-furnished  unfurnished
# 0               0            0
# 1               0            0
# 2               1            0
# 3               0            0
# 4               0            0

# %% [markdown]
# ### 3) Splitting the data set

# %%
df_train,df_test=train_test_split(housing,train_size=0.7,random_state= 100)

# %%
df_test.head()
# Out:
#        price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 265  4403000   2880         3          1        2         1          0
# 54   7350000   6000         3          2        2         1          1
# 171  5250000  10269         3          1        1         1          0
# 244  4550000   5320         3          1        2         1          1
# 268  4382000   4950         4          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 265         0                0                0        0         1
# 54          0                0                1        1         0
# 171         0                0                0        1         1
# 244         1                0                0        0         1
# 268         0                0                1        0         0
#
#      semi-furnished  unfurnished
# 265               1            0
# 54                1            0
# 171               1            0
# 244               1            0
# 268               1            0

# %%
df_train.head()
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 359  3710000  3600         3          1        1         1          0
# 19   8855000  6420         3          2        2         1          0
# 159  5460000  3150         3          2        1         1          1
# 35   8080940  7000         3          2        4         1          0
# 28   8400000  7950         5          2        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 359         0                0                0        1         0
# 19          0                0                1        1         1
# 159         1                0                1        0         0
# 35          0                0                1        2         0
# 28          1                1                0        2         0
#
#      semi-furnished  unfurnished
# 359               0            1
# 19                1            0
# 159               0            0
# 35                0            0
# 28                0            1

# %% [markdown]
# ###  4) Scaling of the Variables

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
# Applying minmax scaler to the columns except with the ones with 0 and 1
mlist=["price","area","bedrooms","bathrooms","stories","parking"]
df_train[mlist]=scaler.fit_transform(df_train[mlist])
df_test[mlist]=scaler.transform(df_test[mlist])

# %%
df_train.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 359  0.169697  0.155227       0.4        0.0  0.000000         1          0
# 19   0.615152  0.403379       0.4        0.5  0.333333         1          0
# 159  0.321212  0.115628       0.4        0.5  0.000000         1          1
# 35   0.548133  0.454417       0.4        0.5  1.000000         1          0
# 28   0.575758  0.538015       0.8        0.5  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 359         0                0                0  0.333333         0
# 19          0                0                1  0.333333         1
# 159         1                0                1  0.000000         0
# 35          0                0                1  0.666667         0
# 28          1                1                0  0.666667         0
#
#      semi-furnished  unfurnished
# 359               0            1
# 19                1            0
# 159               0            0
# 35                0            0
# 28                0            1

# %%
df_test.head()
# Out:
#         price      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265  0.229697  0.091869       0.4        0.0  0.333333         1          0
# 54   0.484848  0.366420       0.4        0.5  0.333333         1          1
# 171  0.303030  0.742080       0.4        0.0  0.000000         1          0
# 244  0.242424  0.306582       0.4        0.0  0.333333         1          1
# 268  0.227879  0.274023       0.6        0.0  0.333333         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
#
#      semi-furnished  unfurnished
# 265               1            0
# 54                1            0
# 171               1            0
# 244               1            0
# 268               1            0

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_train.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Modelling

# %%
# Splitting  the variables into X and Y
y_train=df_train["price"]
df_train.drop("price",axis=1,inplace=True)

# %%
df_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 359  0.155227       0.4        0.0  0.000000         1          0         0
# 19   0.403379       0.4        0.5  0.333333         1          0         0
# 159  0.115628       0.4        0.5  0.000000         1          1         1
# 35   0.454417       0.4        0.5  1.000000         1          0         0
# 28   0.538015       0.8        0.5  0.333333         1          0         1
#
#      hotwaterheating  airconditioning   parking  prefarea  semi-furnished  \
# 359                0                0  0.333333         0               0
# 19                 0                1  0.333333         1               1
# 159                0                1  0.000000         0               0
# 35                 0                1  0.666667         0               0
# 28                 1                0  0.666667         0               0
#
#      unfurnished
# 359            1
# 19             0
# 159            0
# 35             0
# 28             1

# %%
y_train
# Out:
# 359    0.169697
# 19     0.615152
# 159    0.321212
# 35     0.548133
# 28     0.575758
#          ...
# 526    0.048485
# 53     0.484848
# 350    0.175758
# 79     0.424242
# 520    0.060606
# Name: price, Length: 381, dtype: float64

# %%
X_train=df_train

# %%
X_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 359  0.155227       0.4        0.0  0.000000         1          0         0
# 19   0.403379       0.4        0.5  0.333333         1          0         0
# 159  0.115628       0.4        0.5  0.000000         1          1         1
# 35   0.454417       0.4        0.5  1.000000         1          0         0
# 28   0.538015       0.8        0.5  0.333333         1          0         1
#
#      hotwaterheating  airconditioning   parking  prefarea  semi-furnished  \
# 359                0                0  0.333333         0               0
# 19                 0                1  0.333333         1               1
# 159                0                1  0.000000         0               0
# 35                 0                1  0.666667         0               0
# 28                 1                0  0.666667         0               0
#
#      unfurnished
# 359            1
# 19             0
# 159            0
# 35             0
# 28             1

# %%
X_trainlm=sm.add_constant(X_train)

# %%
lr=sm.OLS(y_train,X_trainlm).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Sun, 08 Jan 2023   Prob (F-statistic):           8.83e-83
# Time:                        14:49:06   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -735.6
# Df Residuals:                     367   BIC:                            -680.4
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0200      0.021      0.955      0.340      -0.021       0.061
# area                0.2347      0.030      7.795      0.000       0.175       0.294
# bedrooms            0.0467      0.037      1.267      0.206      -0.026       0.119
# bathrooms           0.1908      0.022      8.679      0.000       0.148       0.234
# stories             0.1085      0.019      5.661      0.000       0.071       0.146
# mainroad            0.0504      0.014      3.520      0.000       0.022       0.079
# guestroom           0.0304      0.014      2.233      0.026       0.004       0.057
# basement            0.0216      0.011      1.943      0.053      -0.000       0.043
# hotwaterheating     0.0849      0.022      3.934      0.000       0.042       0.127
# airconditioning     0.0669      0.011      5.899      0.000       0.045       0.089
# parking             0.0607      0.018      3.365      0.001       0.025       0.096
# prefarea            0.0594      0.012      5.040      0.000       0.036       0.083
# semi-furnished      0.0009      0.012      0.078      0.938      -0.022       0.024
# unfurnished        -0.0310      0.013     -2.440      0.015      -0.056      -0.006
# ==============================================================================
# Omnibus:                       93.687   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              304.917
# Skew:                           1.091   Prob(JB):                     6.14e-67
# Kurtosis:                       6.801   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Calculating VIF to identify the redundant variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif=pd.DataFrame()
vif["Features"]=X_train.columns
vif["VIF"]=[variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif["VIF"]=round(vif["VIF"],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  7.33
# 4          mainroad  6.02
# 0              area  4.67
# 3           stories  2.70
# 11   semi-furnished  2.19
# 9           parking  2.12
# 6          basement  2.02
# 12      unfurnished  1.82
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 7   hotwaterheating  1.14

# %%
# Removing the Semi Furnished column
X=X_train.drop("semi-furnished",1,inplace=True)

# %%
# Building the Model
X_trainlm=sm.add_constant(X_train)
lr=sm.OLS(y_train,X_trainlm).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     65.61
# Date:                Sun, 08 Jan 2023   Prob (F-statistic):           1.07e-83
# Time:                        14:49:06   Log-Likelihood:                 381.79
# No. Observations:                 381   AIC:                            -737.6
# Df Residuals:                     368   BIC:                            -686.3
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0207      0.019      1.098      0.273      -0.016       0.058
# area                0.2344      0.030      7.845      0.000       0.176       0.293
# bedrooms            0.0467      0.037      1.268      0.206      -0.026       0.119
# bathrooms           0.1909      0.022      8.697      0.000       0.148       0.234
# stories             0.1085      0.019      5.669      0.000       0.071       0.146
# mainroad            0.0504      0.014      3.524      0.000       0.022       0.079
# guestroom           0.0304      0.014      2.238      0.026       0.004       0.057
# basement            0.0216      0.011      1.946      0.052      -0.000       0.043
# hotwaterheating     0.0849      0.022      3.941      0.000       0.043       0.127
# airconditioning     0.0668      0.011      5.923      0.000       0.045       0.089
# parking             0.0608      0.018      3.372      0.001       0.025       0.096
# prefarea            0.0594      0.012      5.046      0.000       0.036       0.083
# unfurnished        -0.0316      0.010     -3.096      0.002      -0.052      -0.012
# ==============================================================================
# Omnibus:                       93.538   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              303.844
# Skew:                           1.090   Prob(JB):                     1.05e-66
# Kurtosis:                       6.794   Cond. No.                         14.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again Calculating the VIF
vif=pd.DataFrame()
vif["Features"]=X_train.columns
vif["VIF"]=[variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif["VIF"]=round(vif["VIF"],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features   VIF
# 1          bedrooms  6.59
# 4          mainroad  5.68
# 0              area  4.67
# 3           stories  2.69
# 9           parking  2.12
# 6          basement  2.01
# 8   airconditioning  1.77
# 2         bathrooms  1.67
# 10         prefarea  1.51
# 5         guestroom  1.47
# 11      unfurnished  1.40
# 7   hotwaterheating  1.14

# %%
# Removing the Bedrooms as its P value and VIF is high
X=X_train.drop("bedrooms",1,inplace=True)

# %%
# Building the Model
X_trainlm=sm.add_constant(X_train)
lr=sm.OLS(y_train,X_trainlm).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     71.31
# Date:                Sun, 08 Jan 2023   Prob (F-statistic):           2.73e-84
# Time:                        14:49:06   Log-Likelihood:                 380.96
# No. Observations:                 381   AIC:                            -737.9
# Df Residuals:                     369   BIC:                            -690.6
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0357      0.015      2.421      0.016       0.007       0.065
# area                0.2347      0.030      7.851      0.000       0.176       0.294
# bathrooms           0.1965      0.022      9.132      0.000       0.154       0.239
# stories             0.1178      0.018      6.654      0.000       0.083       0.153
# mainroad            0.0488      0.014      3.423      0.001       0.021       0.077
# guestroom           0.0301      0.014      2.211      0.028       0.003       0.057
# basement            0.0239      0.011      2.183      0.030       0.002       0.045
# hotwaterheating     0.0864      0.022      4.014      0.000       0.044       0.129
# airconditioning     0.0665      0.011      5.895      0.000       0.044       0.089
# parking             0.0629      0.018      3.501      0.001       0.028       0.098
# prefarea            0.0596      0.012      5.061      0.000       0.036       0.083
# unfurnished        -0.0323      0.010     -3.169      0.002      -0.052      -0.012
# ==============================================================================
# Omnibus:                       97.661   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              325.388
# Skew:                           1.130   Prob(JB):                     2.20e-71
# Kurtosis:                       6.923   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Again Calculating the VIF
vif=pd.DataFrame()
vif["Features"]=X_train.columns
vif["VIF"]=[variance_inflation_factor(X_train.values,i) for i in range(X_train.shape[1])]
vif["VIF"]=round(vif["VIF"],2)
vif=vif.sort_values(by="VIF",ascending=False)
vif
# Out:
#            Features   VIF
# 3          mainroad  4.79
# 0              area  4.55
# 2           stories  2.23
# 8           parking  2.10
# 5          basement  1.87
# 7   airconditioning  1.76
# 1         bathrooms  1.61
# 9          prefarea  1.50
# 4         guestroom  1.46
# 10      unfurnished  1.33
# 6   hotwaterheating  1.12

# %% [markdown]
# #### VIF of main road is less than 5 therefore OK

# %% [markdown]
# # Data Prediction

# %%
y_train_pred=lr.predict(X_trainlm)
y_train
# Out:
# 359    0.169697
# 19     0.615152
# 159    0.321212
# 35     0.548133
# 28     0.575758
#          ...
# 526    0.048485
# 53     0.484848
# 350    0.175758
# 79     0.424242
# 520    0.060606
# Name: price, Length: 381, dtype: float64

# %% [markdown]
# # Residual Anaysis

# %%
res=y_train-y_train_pred
fig=plt.figure(figsize=(10,10))
sns.distplot(res)
fig.suptitle("Residual",fontsize=20)
plt.xlabel("errors")
# Out:
# Text(0.5, 0, 'errors')

# %% [markdown]
# # Making Prediction on Test Data set

# %%
# Splitting in X and Y data set
y_test=df_test.pop("price")
X_test=df_test

# %%
X_trainlm
# Out:
#      const      area  bathrooms   stories  mainroad  guestroom  basement  \
# 359    1.0  0.155227        0.0  0.000000         1          0         0
# 19     1.0  0.403379        0.5  0.333333         1          0         0
# 159    1.0  0.115628        0.5  0.000000         1          1         1
# 35     1.0  0.454417        0.5  1.000000         1          0         0
# 28     1.0  0.538015        0.5  0.333333         1          0         1
# ..     ...       ...        ...       ...       ...        ...       ...
# 526    1.0  0.118268        0.0  0.000000         1          0         0
# 53     1.0  0.291623        0.5  1.000000         1          0         0
# 350    1.0  0.139388        0.0  0.333333         1          0         0
# 79     1.0  0.366420        0.5  0.666667         1          1         0
# 520    1.0  0.516015        0.0  0.000000         1          0         0
#
#      hotwaterheating  airconditioning   parking  prefarea  unfurnished
# 359                0                0  0.333333         0            1
# 19                 0                1  0.333333         1            0
# 159                0                1  0.000000         0            0
# 35                 0                1  0.666667         0            0
# 28                 1                0  0.666667         0            1
# ..               ...              ...       ...       ...          ...
# 526                0                0  0.000000         0            1
# 53                 0                1  0.666667         0            0
# 350                1                0  0.333333         0            0
# 79                 0                1  0.000000         0            0
# 520                0                0  0.000000         0            1
#
# [381 rows x 12 columns]

# %%
X_testlm=sm.add_constant(X_test)
X_testlm
# Out:
#      const      area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 265    1.0  0.091869       0.4        0.0  0.333333         1          0
# 54     1.0  0.366420       0.4        0.5  0.333333         1          1
# 171    1.0  0.742080       0.4        0.0  0.000000         1          0
# 244    1.0  0.306582       0.4        0.0  0.333333         1          1
# 268    1.0  0.274023       0.6        0.0  0.333333         1          0
# ..     ...       ...       ...        ...       ...       ...        ...
# 413    1.0  0.010032       0.4        0.5  0.333333         1          0
# 191    1.0  0.780007       0.4        0.0  0.333333         1          1
# 310    1.0  0.365100       0.4        0.0  0.000000         1          0
# 46     1.0  0.366420       0.4        0.5  1.000000         1          0
# 50     1.0  0.493136       0.4        0.5  1.000000         1          0
#
#      basement  hotwaterheating  airconditioning   parking  prefarea  \
# 265         0                0                0  0.000000         1
# 54          0                0                1  0.333333         0
# 171         0                0                0  0.333333         1
# 244         1                0                0  0.000000         1
# 268         0                0                1  0.000000         0
# ..        ...              ...              ...       ...       ...
# 413         1                0                0  0.000000         1
# 191         1                0                0  0.000000         0
# 310         1                0                0  0.000000         0
# 46          0                0                1  0.333333         0
# 50          0                0                0  0.333333         1
#
#      semi-furnished  unfurnished
# 265               1            0
# 54                1            0
# 171               1            0
# 244               1            0
# 268               1            0
# ..              ...          ...
# 413               0            1
# 191               1            0
# 310               1            0
# 46                0            0
# 50                0            1
#
# [164 rows x 14 columns]

# %%
X=X_testlm.drop(["semi-furnished", "bedrooms"],axis=1,inplace=True)

# %%
y_test_pred=lr.predict(X_testlm)
y_test_pred
# Out:
# 265    0.204980
# 54     0.425613
# 171    0.339321
# 244    0.309397
# 268    0.254629
#          ...
# 413    0.275609
# 191    0.360889
# 310    0.194143
# 46     0.474017
# 50     0.464556
# Length: 164, dtype: float64

# %% [markdown]
# # Model Evaluation

# %%
r2=r2_score(y_true=y_test,y_pred=y_test_pred)
print(r2)
# Out:
# 0.6713505684480789

# %% [markdown]
# ### The model is correctly able to identify the 67.13% variation on the test dataset
